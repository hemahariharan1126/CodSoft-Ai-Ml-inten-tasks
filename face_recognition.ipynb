# %%
# !pip install opencv-python face-recognition

# %%
import cv2
import face_recognition

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
known_image = face_recognition.load_image_file("/content/download.jpg")
known_encoding = face_recognition.face_encodings(known_image)[0]

known_faces = [known_encoding]
known_names = ["Person"]

# %%
test_image = face_recognition.load_image_file("/content/download.jpg")
test_image_bgr = cv2.cvtColor(test_image, cv2.COLOR_RGB2BGR)
gray = cv2.cvtColor(test_image_bgr, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=5
)

# %%
face_locations = face_recognition.face_locations(test_image)
face_encodings = face_recognition.face_encodings(test_image, face_locations)

for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    matches = face_recognition.compare_faces(known_faces, face_encoding)
    name = "Unknown"

    if True in matches:
        name = known_names[matches.index(True)]

    cv2.rectangle(test_image_bgr, (left, top), (right, bottom), (0, 255, 0), 2)
    cv2.putText(
        test_image_bgr,
        name,
        (left, top - 10),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.9,
        (0, 255, 0),
        2
    )

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(test_image_bgr)

# %%
import nbformat

notebook_path = "/content/Untitled2 (1).ipynb"

nb = nbformat.read(notebook_path, as_version=4)

# Remove problematic widget metadata
if "widgets" in nb.metadata:
    del nb.metadata["widgets"]

nbformat.write(nb, notebook_path)

print("Widget metadata removed successfully.")
# Out:
# Widget metadata removed successfully.
