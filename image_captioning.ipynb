# %% [markdown]
# # Image captioning
# Cleaned notebook (outputs removed). Original cell sources preserved where possible.

# %%
# Example: original code cells kept but outputs cleared
import os
# ... original code cell contents preserved ...
